# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
Pc=40
m=np.arange(0,3,0.025)
Pt=Pc+Pc*(m**m)/2
plt.plot(m,Pt)
plt.title('Potencia en función del Índice de Modulacion' )
plt.xlabel('índice de Modulacion [°/]')
plt.ylabel('Potencia Total [kW]')
# Out:
# Text(0,0.5,'Potencia Total [kW]')

# %%
# Out:
# 1024
